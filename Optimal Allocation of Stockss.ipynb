# %%
# Importing important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Loading DATA
data = pd.read_csv(r'C:\Users\Dhruv Kumar Jha\Downloads\Optimal Allocation of Stocks\StockData.csv')
data
# Out:
#            DATE       INDIGO       ICICI  Jet_Airways         SBI   TATA Chem  \
# 0    01-01-2019  1165.599976  363.750000   280.799988  299.600006  705.299988
# 1    02-01-2019  1161.000000  364.600006   263.549988  293.899994  700.849976
# 2    03-01-2019  1156.550049  363.250000   247.199997  291.100006  694.450012
# 3    04-01-2019  1143.199951  365.200012   245.199997  297.649994  698.450012
# 4    07-01-2019  1113.750000  367.700012   246.199997  296.299988  699.900024
# ..          ...          ...         ...          ...         ...         ...
# 236  23-12-2019  1300.349976  541.299988    25.250000  332.399994  667.900024
# 237  24-12-2019  1306.949951  541.099976    26.500000  331.450012  682.799988
# 238  26-12-2019  1321.949951  538.750000    27.799999  329.850006  668.599976
# 239  27-12-2019  1340.050049  549.400024    29.150000  337.250000  667.500000
# 240  30-12-2019  1343.099976  543.950012    27.700001  334.399994  665.549988
#
#       TATA Comm         HDFC  Bajaj Finance        KOTAK     Reliance
# 0    522.250000  2009.000000    2656.850098  1250.449951  1110.473877
# 1    521.349976  1980.650024    2614.050049  1240.599976  1096.010864
# 2    536.000000  1936.849976    2586.199951  1235.250000  1082.489136
# 3    531.450012  1972.599976    2576.050049  1247.949951  1088.333740
# 4    528.849976  1972.900024    2553.600098  1246.599976  1094.376465
# ..          ...          ...            ...          ...          ...
# 236  386.250000  2422.649902    4160.000000  1704.900024  1556.644531
# 237  395.549988  2412.750000    4139.500000  1711.550049  1531.928833
# 238  391.000000  2414.100098    4187.100098  1694.250000  1501.170410
# 239  391.200012  2444.149902    4252.649902  1685.599976  1527.867310
# 240  385.799988  2438.250000    4243.299805  1690.400024  1529.699951
#
# [241 rows x 11 columns]

# %%
# Dropping irrelevant columns
data.drop(['DATE'], axis = 1, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   INDIGO         241 non-null    float64
#  1   ICICI          241 non-null    float64
#  2   Jet_Airways    241 non-null    float64
#  3   SBI            241 non-null    float64
#  4   TATA Chem      241 non-null    float64
#  5   TATA Comm      241 non-null    float64
#  6   HDFC           241 non-null    float64
#  7   Bajaj Finance  241 non-null    float64
#  8   KOTAK          241 non-null    float64
#  9   Reliance       241 non-null    float64
# dtypes: float64(10)
# memory usage: 19.0 KB

# %%
# Percentage daily return
pct = data.pct_change()
pct.head()
# Out:
#      INDIGO     ICICI  Jet_Airways       SBI  TATA Chem  TATA Comm      HDFC  \
# 0       NaN       NaN          NaN       NaN        NaN        NaN       NaN
# 1 -0.003946  0.002337    -0.061432 -0.019025  -0.006309  -0.001723 -0.014111
# 2 -0.003833 -0.003703    -0.062038 -0.009527  -0.009132   0.028100 -0.022114
# 3 -0.011543  0.005368    -0.008091  0.022501   0.005760  -0.008489  0.018458
# 4 -0.025761  0.006846     0.004078 -0.004536   0.002076  -0.004892  0.000152
#
#    Bajaj Finance     KOTAK  Reliance
# 0            NaN       NaN       NaN
# 1      -0.016109 -0.007877 -0.013024
# 2      -0.010654 -0.004312 -0.012337
# 3      -0.003925  0.010281  0.005399
# 4      -0.008715 -0.001082  0.005552

# %% [markdown]
# ### Calculating the covariance matrix for the stocks :

# %%
cov_matrix = pct.cov()
cov_matrix
# Out:
#                  INDIGO     ICICI  Jet_Airways       SBI  TATA Chem  \
# INDIGO         0.000617  0.000057    -0.000147  0.000048   0.000011
# ICICI          0.000057  0.000322     0.000160  0.000241   0.000102
# Jet_Airways   -0.000147  0.000160     0.006872  0.000208   0.000177
# SBI            0.000048  0.000241     0.000208  0.000480   0.000122
# TATA Chem      0.000011  0.000102     0.000177  0.000122   0.000252
# TATA Comm      0.000059  0.000100    -0.000058  0.000158   0.000097
# HDFC           0.000056  0.000115     0.000102  0.000152   0.000052
# Bajaj Finance  0.000089  0.000190     0.000165  0.000208   0.000096
# KOTAK          0.000050  0.000111     0.000005  0.000115   0.000051
# Reliance       0.000045  0.000067     0.000074  0.000087   0.000015
#
#                TATA Comm      HDFC  Bajaj Finance     KOTAK  Reliance
# INDIGO          0.000059  0.000056       0.000089  0.000050  0.000045
# ICICI           0.000100  0.000115       0.000190  0.000111  0.000067
# Jet_Airways    -0.000058  0.000102       0.000165  0.000005  0.000074
# SBI             0.000158  0.000152       0.000208  0.000115  0.000087
# TATA Chem       0.000097  0.000052       0.000096  0.000051  0.000015
# TATA Comm       0.000993  0.000079       0.000102  0.000070  0.000040
# HDFC            0.000079  0.000220       0.000132  0.000097  0.000034
# Bajaj Finance   0.000102  0.000132       0.000416  0.000142  0.000071
# KOTAK           0.000070  0.000097       0.000142  0.000193  0.000053
# Reliance        0.000040  0.000034       0.000071  0.000053  0.000292

# %% [markdown]
# ### Mean return:

# %%
pct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   INDIGO         240 non-null    float64
#  1   ICICI          240 non-null    float64
#  2   Jet_Airways    240 non-null    float64
#  3   SBI            240 non-null    float64
#  4   TATA Chem      240 non-null    float64
#  5   TATA Comm      240 non-null    float64
#  6   HDFC           240 non-null    float64
#  7   Bajaj Finance  240 non-null    float64
#  8   KOTAK          240 non-null    float64
#  9   Reliance       240 non-null    float64
# dtypes: float64(10)
# memory usage: 19.0 KB

# %%
ind_er = pct.mean()*240 # Multiplying by 240 to get the annual return
ind_er
# Out:
# INDIGO           0.216268
# ICICI            0.440757
# Jet_Airways     -1.585271
# SBI              0.166892
# TATA Chem       -0.028061
# TATA Comm       -0.166241
# HDFC             0.219995
# Bajaj Finance    0.517981
# KOTAK            0.324503
# Reliance         0.354910
# dtype: float64

# %% [markdown]
# ### Portfolio return:

# %%
w = [0.1, 0.2, 0.05, 0.02, 0.1, 0.1, 0.05, 0.21, 0.07, 0.1] #Taking any random weight for different companies
port_er = (w*ind_er).sum()
port_er
# Out:
# 0.19240409932213892

# %% [markdown]
# ### Volatility :

# %%
# Volatility is given by the annual standard deviation.
ann_sd = pct.std().apply(lambda x: x*np.sqrt(240))
ann_sd
# Out:
# INDIGO           0.384953
# ICICI            0.277820
# Jet_Airways      1.284217
# SBI              0.339468
# TATA Chem        0.246118
# TATA Comm        0.488268
# HDFC             0.229976
# Bajaj Finance    0.316035
# KOTAK            0.215026
# Reliance         0.264654
# dtype: float64

# %%
assets = pd.concat([ind_er, ann_sd], axis=1) # Creating a table for visualising returns and volatility of assets
assets.columns = ['Returns', 'Volatility']
assets
# Out:
#                 Returns  Volatility
# INDIGO         0.216268    0.384953
# ICICI          0.440757    0.277820
# Jet_Airways   -1.585271    1.284217
# SBI            0.166892    0.339468
# TATA Chem     -0.028061    0.246118
# TATA Comm     -0.166241    0.488268
# HDFC           0.219995    0.229976
# Bajaj Finance  0.517981    0.316035
# KOTAK          0.324503    0.215026
# Reliance       0.354910    0.264654

# %% [markdown]
# ### Plotting returns vs volatility for 1000 different portfolios with random weights:

# %%
p_ret = [] # Define an empty array for portfolio returns
p_vol = [] # Define an empty array for portfolio volatility
p_weights = [] # Define an empty array for asset weights

num_assets = 10
num_portfolios = 1000
rf = 0.04 # risk factor = 4%

# %%
for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    returns = np.dot(weights, ind_er) # Returns are the product of individual expected returns of asset and its weights. 
    p_ret.append(returns)
    var = cov_matrix.mul(weights, axis=0).mul(weights, axis=1).sum().sum()  # Portfolio Variance
    sd = np.sqrt(var)                                                       # Daily standard deviation
    ann_sd = sd*np.sqrt(240)                                                # Annual standard deviation = volatility
    p_vol.append(ann_sd)
    ratio = np.subtract(p_ret,rf)
    sharpe_ratio = np.divide(ratio, p_vol)

# %%
d = {'Returns':p_ret, 'Volatility':p_vol, 'Sharpe Ratio':sharpe_ratio }

for counter, symbol in enumerate(pct.columns.tolist()):
    #print(counter, symbol)
    d[symbol+' weight'] = [w[counter] for w in p_weights]

# %%
portfolios  = pd.DataFrame(d)
portfolios # Dataframe of the 1000 portfolios created
# Out:
#       Returns  Volatility  Sharpe Ratio  INDIGO weight  ICICI weight  \
# 0    0.041402    0.208503      0.006724       0.023040      0.015531
# 1    0.131191    0.187029      0.487576       0.192405      0.006854
# 2    0.213089    0.180100      0.961068       0.077823      0.067709
# 3    0.090087    0.216973      0.230845       0.009852      0.052562
# 4    0.012626    0.225360     -0.121469       0.131747      0.141841
# ..        ...         ...           ...            ...           ...
# 995  0.053726    0.216904      0.063279       0.067073      0.149222
# 996  0.185238    0.172664      0.841159       0.124382      0.036623
# 997  0.014025    0.246036     -0.105575       0.134727      0.182465
# 998  0.023425    0.233868     -0.070873       0.076231      0.150819
# 999 -0.031478    0.246496     -0.289974       0.098860      0.080492
#
#      Jet_Airways weight  SBI weight  TATA Chem weight  TATA Comm weight  \
# 0              0.101021    0.131347          0.121699          0.046214
# 1              0.044303    0.145039          0.048916          0.127050
# 2              0.003454    0.193388          0.193336          0.063732
# 3              0.059937    0.146232          0.073599          0.217116
# 4              0.117491    0.135393          0.099617          0.062188
# ..                  ...         ...               ...               ...
# 995            0.097045    0.159963          0.088877          0.094608
# 996            0.036188    0.138709          0.106595          0.031407
# 997            0.138234    0.139235          0.023801          0.016472
# 998            0.125331    0.025726          0.158262          0.094282
# 999            0.147936    0.045590          0.135658          0.061033
#
#      HDFC weight  Bajaj Finance weight  KOTAK weight  Reliance weight
# 0       0.183119              0.054912      0.148335         0.174782
# 1       0.097432              0.103753      0.106407         0.127842
# 2       0.014833              0.125559      0.164431         0.095734
# 3       0.097787              0.187691      0.008683         0.146540
# 4       0.108608              0.029939      0.080720         0.092457
# ..           ...                   ...           ...              ...
# 995     0.090611              0.063389      0.036341         0.152872
# 996     0.093333              0.099049      0.185847         0.147869
# 997     0.163781              0.004247      0.144347         0.052690
# 998     0.000457              0.160107      0.071153         0.137632
# 999     0.115277              0.106314      0.066447         0.142393
#
# [1000 rows x 13 columns]

# %% [markdown]
# ### Returns vs Volatility plot:

# %%
# Plot efficient frontier
portfolios.plot.scatter(x='Volatility', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[8,8])

# %% [markdown]
# ### Minimum volatility (left most point):

# %%
min_vol_port = portfolios.iloc[portfolios['Volatility'].idxmin()]
# idxmin() gives us the minimum value in the column specified.                               
min_vol_port
# Out:
# Returns                 0.186101
# Volatility              0.161026
# Sharpe Ratio            0.907315
# INDIGO weight           0.148773
# ICICI weight            0.104573
# Jet_Airways weight      0.033366
# SBI weight              0.010359
# TATA Chem weight        0.216812
# TATA Comm weight        0.002023
# HDFC weight             0.059941
# Bajaj Finance weight    0.048949
# KOTAK weight            0.206654
# Reliance weight         0.168549
# Name: 470, dtype: float64

# %%
# plotting the minimum volatility portfolio
plt.subplots(figsize=[10,10])
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=6, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.xlabel('Volatility')
plt.ylabel('Returns')
# Out:
# Text(0, 0.5, 'Returns')

# %% [markdown]
# ## Optimal Risky Portfolio

# %%
# Finding the optimal portfolio
optimal_risky_port = portfolios.iloc[portfolios['Sharpe Ratio'].idxmax()]
optimal_risky_port
# Out:
# Returns                 0.303722
# Volatility              0.177114
# Sharpe Ratio            1.488998
# INDIGO weight           0.104453
# ICICI weight            0.162098
# Jet_Airways weight      0.002686
# SBI weight              0.088745
# TATA Chem weight        0.114897
# TATA Comm weight        0.015540
# HDFC weight             0.010980
# Bajaj Finance weight    0.180896
# KOTAK weight            0.152645
# Reliance weight         0.167060
# Name: 713, dtype: float64

# %% [markdown]
# ### Plotting optimal portfolio:

# %%
plt.subplots(figsize=(10, 10))
plt.scatter(portfolios['Volatility'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=500)
plt.xlabel('Volatility')
plt.ylabel('Returns')
# Out:
# Text(0, 0.5, 'Returns')

# %% [markdown]
# ###  VAR by Monte Carlo simulation:

# %%
ex_rtn = optimal_risky_port[0]
varsigma = optimal_risky_port[1]

# %% [markdown]
# #### Range of returns in a year

# %%
from scipy.stats import norm
import math
Time = 240 #number of working days in my dataset
lt_price=[]
final_res=[]
for i in range(1000): #1000 runs of simulation
  returns =                     (np.random.normal(ex_rtn/Time,varsigma/math.sqrt(Time),Time))
  plt.plot(returns)
plt.axhline(np.percentile(returns,5), color='r', linestyle='dashed', linewidth=1)
plt.axhline(np.percentile(returns,95), color='g', linestyle='dashed', linewidth=1)
plt.axhline(np.mean(returns), color='b', linestyle='solid', linewidth=1)
plt.show()

# %%
plt.hist(returns,bins=50)
plt.axvline(np.percentile(returns,5), color='r', linestyle='dashed', linewidth=2)
plt.axvline(np.percentile(returns,95), color='r', linestyle='dashed', linewidth=2)
plt.show()

# %%
#VaR
print(np.percentile(returns,5))
print(np.percentile(returns,95))
pvalue = 1000 #portfolio value
print('Amount required to cover minimum losses for one year is ' + str(pvalue* - np.percentile(returns,5)))
# Out:
# -0.01808318784231223
# 0.01764519435340191
# Amount required to cover minimum losses for one year is 18.08318784231223
